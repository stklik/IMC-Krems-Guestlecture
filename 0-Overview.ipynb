# %% [markdown]
# # "Python Frameworks" –– Stefan Klikovits
# IMC Krems; January 10, 2023

# %% [markdown]
# # Stefan Klikovits
# ## Univ. Ass. @ JKU Linz
#
#
# `@stklik`
# [stefan.klikovits@jku.at](mailto:stefan.klikovits@jku.at)
#
#
# [se.jku.at/stefan-klikovits/](https://se.jku.at/stefan-klikovits/) --
# [klikovits.net](https://klikovits.net)

# %% [markdown]
# ![Screenshot%202023-01-05%20at%2014.25.18.png](attachment:Screenshot%202023-01-05%20at%2014.25.18.png)

# %% [markdown]
# # How can I participate in this presentation?

# %% [markdown]
# - Go to https://github.com/stklik/2023-IMC-Krems
# - or click on [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/stklik/2023-IMC-Krems/HEAD)
#
#
# - Select a notebook
# - then: <kbd>Ctrl</kbd> + <kbd>Enter</kbd> to run a cell
# - OR: `Kernel` => `Restart & Run All`

# %% [markdown]
# How this presentation was made:
# - [Jupyter](https://jupyter.org/) Notebooks!
# - Presentation via [RISE plugin](https://github.com/damianavila/RISE)
# - Split slides via *splitcell* extension
# - Your side is served from [Binder](https://mybinder.org/)

# %% [markdown]
# # Goal of this Lecture
#
# - You learned about important, fundamental concepts in this lecture
# - You know what "ingredients" you need to complete a task
# - There are many frameworks out there that help you
# - This is **NOT** a tutorial

# %% [markdown]
# # 1. Fundamental Building Blocks
# - Numpy => data processing
# - Pandas => data analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Data Structures
# - Networks & Graphs => Networkx

# %% [markdown]
# ![image.png](attachment:image.png)
# *Source: https://networkx.org/documentation/stable/tutorial.html*

# %% [markdown]
# # 3. Metaheuristics
# - Genetic Algorithms => pymoo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Where to learn more?
#
# => These are **VERY** popular frameworks
# => Used daily by millions of people
# => Search for e.g. "Numpy + Tutorial"

# %% [markdown]
# # Takeaway message
# Don't reinvent the wheel!
# Use what's out there!

# %% [markdown]
# (But know what you need and use)

# %% [markdown]
# # Questions ?
